# %% [markdown]
# # 1. Импорт библиотек

# %% [markdown]
# import pandas as pd
# import numpy as np
# from pathlib import Path
# import sys
#
# sys.path.append(str(Path("..").resolve()))
#
# from src.config import RAW_DATA_PATH
